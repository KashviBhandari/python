# %%
import tensorflow as tf 
from tensorflow.keras import layers,Sequential

# %%
train = tf.keras.utils.image_dataset_from_directory(
    "C:\\Users\\User\\Desktop\\python\\deeplearing\\archive (1)\\training_set",image_size=(150,150)
)
test = tf.keras .utils.image_dataset_from_directory("C:\\Users\\User\\Desktop\\python\\deeplearing\\archive (1)\\test_set\\test_set",image_size=(150,150)
                                                    )
# Out:
# Found 8005 files belonging to 1 classes.
# Found 2023 files belonging to 2 classes.

# %%
model = Sequential([
    layers.Rescaling(1./255,input_shape = (150,150,3)),
    layers.Conv2D(64,(3,3),activation= "relu"),
    layers.MaxPool2D((2,2)),

    layers.Flatten(),
    layers.Dense(16,activation="relu"),
    layers.Dense(8,activation="relu"),
    layers.Dense(1,activation="sigmoid"),

])
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\preprocessing\data_layer.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss= "binary_crossentropy",optimizer="adam", metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 150, 150, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 148, 148, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 350464)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │     5,607,440 │
# ...

# %%
model.fit(train,
          validation_data=test,
          epochs= 10,
          batch_size = 64)
# Out:
# Epoch 1/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 37s 144ms/step - accuracy: 0.9960 - loss: 0.0045 - val_accuracy: 0.4998 - val_loss: 35.8121
# Epoch 2/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 30s 118ms/step - accuracy: 1.0000 - loss: 5.0424e-12 - val_accuracy: 0.4998 - val_loss: 35.8122
# Epoch 3/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 30s 120ms/step - accuracy: 1.0000 - loss: 5.0423e-12 - val_accuracy: 0.4998 - val_loss: 35.8122
# Epoch 4/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 1.0000 - loss: 5.0421e-12 - val_accuracy: 0.4998 - val_loss: 35.8123
# Epoch 5/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 1.0000 - loss: 5.0419e-12 - val_accuracy: 0.4998 - val_loss: 35.8123
# Epoch 6/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 30s 120ms/step - accuracy: 1.0000 - loss: 5.0417e-12 - val_accuracy: 0.4998 - val_loss: 35.8124
# Epoch 7/10
# 251/251 ━━━━━━━━━━━━━━━━━━━━ 30s 119ms/step - accuracy: 1.0000 - loss: 5.0414e-12 - val_accuracy: 0.4998 - val_loss: 35.8125
# Epoch 8/10
# ...

# %%
model.predict(test)
# Out:
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
# array([[2.2480406e-37],
#        [8.4818346e-33],
#        [2.8060346e-31],
#        ...,
#        [3.1180386e-36],
#        [2.5128506e-37],
#        [1.9309573e-31]], shape=(2023, 1), dtype=float32)
