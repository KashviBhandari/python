# %%
import numpy as npy
import  pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import  StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense 
from tensorflow.keras.optimizers import Adam ,SGD

# %%
df=pd.read_csv("C:\\Users\\User\\Desktop\\python\\student_big_dataset.csv")

# %%
df.head()
# Out:
#   Student_ID  Gender  Age  Study_Hours_per_Day  Attendance_Percentage  \
# 0     S00001    Male   19                  6.5                     96
# 1     S00002  Female   24                  6.0                     50
# 2     S00003    Male   23                  7.4                     93
# 3     S00004    Male   19                  3.9                     55
# 4     S00005    Male   22                  1.8                     50
#
#    Internet_Usage_Hours  Sleep_Hours Parental_Education Extra_Classes  \
# 0                   3.0          8.5        High School            No
# 1                   0.7          8.3       Postgraduate            No
# 2                   4.6          8.2        High School           Yes
# 3                   5.2          8.3       Postgraduate           Yes
# 4                   2.2          5.5        High School            No
#
#   Stress_Level  Final_Score
# 0          Low         96.0
# 1       Medium         74.0
# 2          Low         87.0
# ...

# %%
categorical_binary = ["Extra_Classes","Stress_Level","Gender"]
categorical_multi= ["Parental_Education"]

# %%
num = ["Study_Hours_per_Day","Attendance_Percentage","Internet_Usage_Hours"	,"Sleep_Hours","Final_Score"]

# %%
label=LabelEncoder()
for col in categorical_binary:
    df[col] = label.fit_transform(df[col])

# %%
df= pd.get_dummies(df, 
                    columns=[col for col in categorical_multi if col in df.columns], 
                    drop_first=True)

# %%
x=df[['Study_Hours_per_Day',"Attendance_Percentage","Internet_Usage_Hours"]]
y=df["Final_Score"]

# %%
x_train ,x_test ,y_train ,y_test = train_test_split(x,y, test_size= 0.2 , random_state= 42)

# %%
scaler= StandardScaler()
scaler.fit_transform(x_train)
scaler.transform(x_test)
# Out:
# array([[-0.20306733, -0.27241807, -0.79232645],
#        [-0.61783139, -0.81999207,  1.5675783 ],
#        [ 1.08730974,  0.54894294,  1.28994245],
#        ...,
#        [-0.06481264,  1.09651695, -0.88487174],
#        [-1.17085013, -0.68309857,  0.87348867],
#        [ 1.50207379, -1.02533233,  1.52130566]], shape=(2000, 3))

# %%
model = Sequential([Dense(32, activation= 'relu', input_dim= x_test.shape[1]),
                    Dense(16,activation='relu'),
                    Dense(1,activation= 'sigmoid')])
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='categorical_crossentropy',optimizer=Adam(0.001), metrics=rom sklearn.compose import ColumnTransformer  )

# %%
histroy=model.fit(x_train,y_train ,epochs=10 ,batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/10
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(32, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_loss: 0.0000e+00
# Epoch 2/10
#  62/200 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# c:\Users\User\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\losses\losses.py:33: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(32, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
# ...

# %%
model.compile(loss="mse", optimizer=SGD(learning_rate=0.01), metrics=)['accuracy']
history = model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0000e+00 - loss: 3720.2378 - val_accuracy: 0.0000e+00 - val_loss: 3704.1243
# Epoch 2/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 3720.2412 - val_accuracy: 0.0000e+00 - val_loss: 3704.1243
# Epoch 3/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 3720.2407 - val_accuracy: 0.0000e+00 - val_loss: 3704.1243
# Epoch 4/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 3720.2400 - val_accuracy: 0.0000e+00 - val_loss: 3704.1243
# Epoch 5/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - accuracy: 0.0000e+00 - loss: 3720.2390 - val_accuracy: 0.0000e+00 - val_loss: 3704.1243
# Epoch 6/50
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 3720.2397 - val_accuracy: 0.0000e+00 - val_loss: 3704.1243
# Epoch 7/50
# ...

# %%
loss ,accuracy = model.evaluate(x_test,y_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 3594.6116

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history["val_loss"],label =" validation"  )
plt.plot(history.history["loss"],label = "loss")
plt.show()

# %%
plt.plot(model.evaluate(x_test,y_test)) 
plt.plot(accuracy)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - accuracy: 0.0000e+00 - loss: 3594.6116
