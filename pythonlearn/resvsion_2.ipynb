# %%
class student:
     def __init__(self , name , roll_no , marks ):
          self.name = name 
          self. roll_no = roll_no 
          self.marks =marks
     def display_Detalis(self):
          print("name :",self.name)
          print("roll_no",self.roll_no)
          print("marks", self.marks)

st1 = student("aman", 101 , 85)

st1.display_Detalis()
# Out:
# name : aman
# roll_no 101
# marks 85

# %%
class emplooye :
    def __init__(self ,name, emp_id, department, salary):
         self.name = name
         self.emp_id =emp_id
         self.department = department
         self.salary =salary

    def display_info(self):
         print("name", self.name)
         print("emp_id", self. emp_id)
         print("departemnt", self.department)
         print("salary", self.salary)

emp1 = emplooye("jay",19 , "HR", 45000)
emp2= emplooye("vijay", 27 , "HR",35000)

emp2.display_info()
# Out:
# name vijay
# emp_id 27
# departemnt HR
# salary 35000

# %%
class customer:
    def __init__(self, name, account_no, balance):
        self.name = name 
        self.account =  account_no
        self
