# %% [markdown]
# Basic Programs
# Write a Python program to print "Hello, World!".
# Write a program to input your name and print:

# %%
name = input("What's your name? ")
print("hello" , name)
# Out:
# hello Kashvi

# %% [markdown]
# Write a program to find the sum of two numbers entered by the user.

# %%
a = int(input("enter:"))
b = int(input("enter:"))
print("sum =", a+b)
print("difference =", a-b)
print("product =", a*b)
print("quotient =", a/b)
# Out:
# sum = 7
# difference = -1
# product = 12
# quotient = 0.75

# %%
name =input("What's your name? ")
age = input("What's your age? ")
print("hello" , name, "you are", age, "years old")
# Out:
# hello kashvi you are 17 years old

# %%
length = float(input("enter length:"))
breadth  = float(input("enter breadth:"))
area =length*breadth
print(area)
# Out:
# 375.0

# %%
num =float(input("enter a number:"))
num = int(num)
print(num)
# Out:
# 3

# %%
for i in range(5):
    if i == 2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4

# %%
a = int(input("enter a number:"))
b = int(input("enter another number:"))
print("1.Addition")
print("2.Subtraction")
print("3.Multiplication")
print("4.Division")
choice = int(input("enter your choice:"))
if choice == 1:
    print("sum =", a+b)
elif choice == 2:
    print("difference =", a-b)
elif choice == 3:
    print("product =", a*b)
elif choice == 4:
    print("quotient =", a/b)
else:
    print("invalid choice")
# Out:
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# quotient = 1.0

# %%
a = int(input("enter a number:"))
B = int(input("enter another number:"))
print("1.Addition")
print("2.Subtraction")
print("3.Multiplication")       
print("4.Division")
choice = int(input("enter your choice:"))
if choice == 1:
    print("sum =", a+B)
elif choice== 2:
    print("difference =", a-B)
elif choice == 3:
    print("product =", a*B)
elif choice == 4:
    print("quotient =", a/B)
# Out:
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# quotient = 0.9824561403508771

# %%
maths = int(input("enter marks:"))
sci = int(input("enter marks:"))
sst =int(input("enter marks:"))
total = maths + sci + sst
print("total",total)

if total >= 32:
    print("pass")
    
elif  total>=65
 p

# %%
largest = 0
second_largest = 0
for  n in range(6):
  num = int(input(""))
  if num > largest:
   thirdlargest =second_largest
   second_largest =largest
   largest =num
   print(largest)
  elif num > second_largest and num != largest:
    second_largest = num 
  elif num > thirdlargest and num!= second_largest and num != largest:
    thirdlargest =num
print("Largest:", largest)
print("Second Largest:", second_largest)
print(largest - second_largest)
print("thirdlargest",thirdlargest)
# Out:
# 45
# 60
# 584
# Largest: 584
# Second Largest: 485
# 99
# thirdlargest 473

# %%
for  i in range(10):
    print("kashvi")
# Out:
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi

# %%
name = ("kashvi""\n")*10
print(name)
# Out:
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi
# kashvi

# %%
diameter = int(input("enter value"))
radius = diameter/2
area = 3.14*(radius**2)
print(radius)
print(area)
print(type(area))
# Out:
# 3.0
# 28.26
# <class 'float'>

# %%
age = int(input("enter your age :"))
print("age:", age)
print("datatype", type(age))
# Out:
# age: 17
# datatype <class 'int'>
