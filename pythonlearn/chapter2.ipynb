# %% [markdown]
# data type

# %%
age = int(input("enter your age :"))
print("age:", age)
print("datatype", type(age))
# Out:
# age: 17
# datatype <class 'int'>

# %%
a = int(input("enter no "))
b = int(input("enter no "))
sum = a + b

avg = sum/2
print("sum :",sum)
print(avg)
# Out:
# sum : 12
# 6.0

# %%
x = 7
y = 7.5
z = x+y
print("datatype" , x, type(x))
print("datatype" , y,type(y))
print("datatype" , z, type(z))
print(int(y), )
# Out:
# datatype 7 <class 'int'>
# datatype 7.5 <class 'float'>
# datatype 14.5 <class 'float'>
# 7

# %% [markdown]
# conversion

# %%
num =input("enter num")
converted = float(num)
print(num ,type(num))
print(converted, type(converted))
# Out:
# 4 <class 'str'>
# 4.0 <class 'float'>

# %% [markdown]
# opertor

# %%
x = 10
y = 5
#==========arithmetic============
print(x+y) #add
print(x -y)#
print(x*y)# 
print(x**y)#power
print(x/y)#divisin
print(x%y)#reminder
#=============comparison==========
print(x==y)# is equla
print( x >= y)# grearter than
print(x <= y)# less than 
#============logical=========
print(x > y and x < y) 
print(x > y or x < y)
print(not(x > y))
# Out:
# 15
# 5
# 50
# 100000
# 2.0
# 0
# False
# True
# False
# False
# True
# False

# %% [markdown]
# write a  program  that takes two number and prints

# %%
a= int(input())
b = int(input())
print("sum",a+b)
print("difference", a- b)
print("product", a*b)
print("first no is greater than second", a>=b)
# Out:
# sum 15
# difference 5
# product 50
# first no is greater than second True

# %%
temperature = float(input())
fahrenheit = (temperature*9/5)+32
kelvin =  temperature + 273.15
print("Temperature",temperature)
print("fahrenheit",fahrenheit)
print("kelvin", kelvin)
# Out:
# Temperature 25.0
# fahrenheit 77.0
# kelvin 298.15

# %%
bill =   float(input())
friends =  4
print("bill", bill)
print("each will pay:", bill/4)
# Out:
# bill 1000.0
# each will pay: 250.0
