# %%
import nltk

# %%
sentence = """"It was just another ordinary morning. Riya woke up late, rushed through her breakfast, and almost missed her bus to college. “Nothing special today,” she thought.

But that day had other plans.

On her way, she noticed an old man struggling to cross the road. Normally, she would have walked past—she was already late—but something made her stop. She helped him cross. The old man smiled and said, “Kindness always comes back.”

Riya didn’t think much of it and hurried to class. Later that day, her teacher announced a surprise presentation. Riya panicked—she wasn’t prepared at all. Just when she thought she would fail, her friend unexpectedly shared notes and helped her quickly understand the topic.

Riya gave her presentation… and to her surprise, it went really well.

In the evening, while returning home, she again saw the same old man sitting peacefully. He waved at her, and she smiled back. That moment made her realize something simple but powerful—

Small actions can change the whole day.

That night, Riya went to sleep thinking, “Maybe today wasn’t ordinary after all.”"""

# %%
sentence= sentence.lower()
sentence
# Out:
# '"it was just another ordinary morning. riya woke up late, rushed through her breakfast, and almost missed her bus to college. “nothing special today,” she thought.\n\nbut that day had other plans.\n\non her way, she noticed an old man struggling to cross the road. normally, she would have walked past—she was already late—but something made her stop. she helped him cross. the old man smiled and said, “kindness always comes back.”\n\nriya didn’t think much of it and hurried to class. later that day, her teacher announced a surprise presentation. riya panicked—she wasn’t prepared at all. just when she thought she would fail, her friend unexpectedly shared notes and helped her quickly understand the topic.\n\nriya gave her presentation… and to her surprise, it went really well.\n\nin the evening, while returning home, she again saw the same old man sitting peacefully. he waved at her, and she smiled back. that moment made her realize something simple but powerful—\n\nsmall actions can c
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
token = word_tokenize(sentence)
token
# Out:
# ['``',
#  'it',
#  'was',
#  'just',
#  'another',
#  'ordinary',
#  'morning',
#  '.',
#  'riya',
#  'woke',
#  'up',
#  'late',
#  ',',
#  'rushed',
#  'through',
#  'her',
#  'breakfast',
#  ',',
#  'and',
#  'almost',
#  'missed',
#  'her',
#  'bus',
#  'to',
#  'college',
#  '.',
#  '“',
#  'nothing',
#  'special',
#  'today',
#  ',',
#  '”',
#  'she',
#  'thought',
#  '.',
#  'but',
#  'that',
#  'day',
#  'had',
#  'other',
#  'plans',
#  '.',
#  'on',
#  'her',
#  'way',
#  ',',
#  'she',
#  'noticed',
#  'an',
#  'old',
#  'man',
#  'struggling',
#  'to',
#  'cross',
#  'the',
#  'road',
#  '.',
#  'normally',
#  ',',
#  'she',
#  'would',
#  'have',
#  'walked',
#  'past',
#  '—',
#  'she',
#  'was',
#  'already',
#  'late',
#  '—',
#  'but',
#  'something',
#  'made',
#  'her',
#  'stop',
#  '.',
#  'she',
#  'helped',
#  'him',
#  'cross',
#  '.',
#  'the',
#  'old',
#  'man',
#  'smiled',
#  'and',
#  'said',
#  ',',
#  '“',
#  'kindness',
#  'always',
#  'comes',
# ...

# %%
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
xy= stopwords

# %%
xy= stopwords.words('english')

# %%
for i in token:
    if i in xy:
     token.remove(i)
token
# Out:
# ['``',
#  'was',
#  'another',
#  'ordinary',
#  'morning',
#  '.',
#  'riya',
#  'woke',
#  'late',
#  ',',
#  'rushed',
#  'breakfast',
#  ',',
#  'almost',
#  'missed',
#  'bus',
#  'college',
#  '.',
#  '“',
#  'nothing',
#  'special',
#  'today',
#  ',',
#  '”',
#  'thought',
#  '.',
#  'day',
#  'other',
#  'plans',
#  '.',
#  'way',
#  ',',
#  'noticed',
#  'old',
#  'man',
#  'struggling',
#  'cross',
#  'road',
#  '.',
#  'normally',
#  ',',
#  'would',
#  'walked',
#  'past',
#  '—',
#  'was',
#  'already',
#  'late',
#  '—',
#  'something',
#  'made',
#  'stop',
#  '.',
#  'helped',
#  'cross',
#  '.',
#  'old',
#  'man',
#  'smiled',
#  'said',
#  ',',
#  '“',
#  'kindness',
#  'always',
#  'comes',
#  'back.',
#  '”',
#  'riya',
#  '’',
#  'think',
#  'much',
#  'hurried',
#  'class',
#  '.',
#  'later',
#  'day',
#  ',',
#  'teacher',
#  'announced',
#  'surprise',
#  'presentation',
#  '.',
#  'riya',
#  'panicked',
#  '—',
#  '’',
#  'prepared',
#  'all',
#  '.',
# ...

# %%
for i in token:
     if not i.isalnum():
      token.remove(i)
token
# Out:
# ['was',
#  'another',
#  'ordinary',
#  'morning',
#  'riya',
#  'woke',
#  'late',
#  'rushed',
#  'breakfast',
#  'almost',
#  'missed',
#  'bus',
#  'college',
#  '“',
#  'nothing',
#  'special',
#  'today',
#  '”',
#  'thought',
#  'day',
#  'other',
#  'plans',
#  'way',
#  'noticed',
#  'old',
#  'man',
#  'struggling',
#  'cross',
#  'road',
#  'normally',
#  'would',
#  'walked',
#  'past',
#  'was',
#  'already',
#  'late',
#  'something',
#  'made',
#  'stop',
#  'helped',
#  'cross',
#  'old',
#  'man',
#  'smiled',
#  'said',
#  '“',
#  'kindness',
#  'always',
#  'comes',
#  '”',
#  'riya',
#  'think',
#  'much',
#  'hurried',
#  'class',
#  'later',
#  'day',
#  'teacher',
#  'announced',
#  'surprise',
#  'presentation',
#  'riya',
#  'panicked',
#  'prepared',
#  'all',
#  'when',
#  'thought',
#  'would',
#  'fail',
#  'friend',
#  'unexpectedly',
#  'shared',
#  'notes',
#  'helped',
#  'quickly',
#  'understand',
#  'topic',
#  'riya',
#  'gave',
#  'her',
# ...

# %%
from nltk.stem import  PorterStemmer, WordNetLemmatizer

# %%
ps = PorterStemmer()

# %%
ps.stem("better")
# Out:
# 'better'

# %%
stemedtokens = []
for i in token:
    stemedtokens.append(ps.stem(i))
stemedtokens
# Out:
# ['wa',
#  'anoth',
#  'ordinari',
#  'morn',
#  'riya',
#  'woke',
#  'late',
#  'rush',
#  'breakfast',
#  'almost',
#  'miss',
#  'bu',
#  'colleg',
#  '“',
#  'noth',
#  'special',
#  'today',
#  '”',
#  'thought',
#  'day',
#  'other',
#  'plan',
#  'way',
#  'notic',
#  'old',
#  'man',
#  'struggl',
#  'cross',
#  'road',
#  'normal',
#  'would',
#  'walk',
#  'past',
#  'wa',
#  'alreadi',
#  'late',
#  'someth',
#  'made',
#  'stop',
#  'help',
#  'cross',
#  'old',
#  'man',
#  'smile',
#  'said',
#  '“',
#  'kind',
#  'alway',
#  'come',
#  '”',
#  'riya',
#  'think',
#  'much',
#  'hurri',
#  'class',
#  'later',
#  'day',
#  'teacher',
#  'announc',
#  'surpris',
#  'present',
#  'riya',
#  'panick',
#  'prepar',
#  'all',
#  'when',
#  'thought',
#  'would',
#  'fail',
#  'friend',
#  'unexpectedli',
#  'share',
#  'note',
#  'help',
#  'quickli',
#  'understand',
#  'topic',
#  'riya',
#  'gave',
#  'her',
#  'surpris',
#  'it',
#  'went',
#  'realli',
#  'well',
# ...

# %%
wnl = WordNetLemmatizer()

# %%
wnl.lemmatize( "best" , pos= 'a')
# Out:
# 'best'

# %%
import nltk
from nltk import pos_tag 
from nltk.chunk import ne_chunk
from nltk.tokenize import word_tokenize

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
snt= 'Riya gave her presentation… and to her surprise, it went really well.'

# %%
token =word_tokenize(snt)

# %%
token
# Out:
# ['Riya',
#  'gave',
#  'her',
#  'presentation…',
#  'and',
#  'to',
#  'her',
#  'surprise',
#  ',',
#  'it',
#  'went',
#  'really',
#  'well',
#  '.']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
postags =nltk.pos_tag(token)

# %%
postags
# Out:
# [('Riya', 'NNP'),
#  ('gave', 'VBD'),
#  ('her', 'PRP$'),
#  ('presentation…', 'NN'),
#  ('and', 'CC'),
#  ('to', 'TO'),
#  ('her', 'PRP$'),
#  ('surprise', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('went', 'VBD'),
#  ('really', 'RB'),
#  ('well', 'RB'),
#  ('.', '.')]

# %%
from nltk.chunk import ne_chunk

# %%
import svgling

# %%
chunked= nltk.ne_chunk(postags)
print(chunked)
# Out:
# (S
#   (PERSON Riya/NNP)
#   gave/VBD
#   her/PRP$
#   presentation…/NN
#   and/CC
#   to/TO
#   her/PRP$
#   surprise/NN
#   ,/,
#   it/PRP
#   went/VBD
#   really/RB
#   well/RB
#   ./.)

# %%
# %pip install  textblob
# Out:
# ...
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 5.9 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from  textblob import TextBlob

# %%
text= " this is was very bad   "

# %%
blob =TextBlob(text)
sentiment =blob.sentiment

# %%
"Polarity:", sentiment.polarity
"Subjectivity:", sentiment.subjectivity
# Out:
# ('Subjectivity:', 0.8666666666666667)

# %%
if sentiment.polarity > 0:
  print("Overall Sentiment: Positive")
elif sentiment.polarity < 0:
 print("Overall Sentiment: Negative")
else:
 print("Overall Sentiment: Neutral")
# Out:
# Overall Sentiment: Negative

# %%
import nltk
from nltk .sentiment.vader import SentimentIntensityAnalyzer

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# True

# %%
sin = SentimentIntensityAnalyzer()
sin.polarity_scores("that is very bad")
# Out:
# {'neg': 0.558, 'neu': 0.442, 'pos': 0.0, 'compound': -0.5849}
